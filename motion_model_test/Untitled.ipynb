# %%
import os
import shutil
import random

# %% [markdown]
# shutil.copy('/Users/Abder/Desktop/sample.pdf', '/Users/Abder/Desktop/Temp')

# %%
root_path = '/home/pirl/Documents/final_motion_npz'
save_path = "/home/pirl/Documents/selected_motion_data10000/"

# %%
print(len(os.listdir(root_path)))
# Out:
# 139335

# %%
numlist =range(len(os.listdir(root_path)))

s = random.sample(numlist, 10000)
s.sort()
print(s)
# Out:
# [5, 8, 9, 11, 13, 42, 46, 62, 71, 88, 99, 113, 115, 123, 127, 158, 171, 174, 189, 196, 209, 214, 218, 233, 238, 242, 245, 286, 292, 304, 306, 321, 330, 333, 338, 376, 378, 386, 398, 408, 425, 447, 455, 459, 465, 466, 467, 492, 495, 501, 510, 511, 526, 533, 537, 540, 543, 551, 554, 601, 605, 650, 663, 664, 676, 680, 698, 705, 708, 714, 716, 743, 771, 785, 790, 852, 897, 909, 915, 927, 955, 976, 992, 1006, 1017, 1038, 1039, 1040, 1079, 1083, 1103, 1111, 1123, 1127, 1131, 1141, 1163, 1167, 1173, 1174, 1178, 1204, 1211, 1221, 1231, 1235, 1241, 1242, 1255, 1268, 1275, 1291, 1298, 1300, 1346, 1353, 1359, 1380, 1401, 1403, 1412, 1456, 1485, 1488, 1493, 1501, 1502, 1506, 1511, 1512, 1528, 1536, 1550, 1551, 1561, 1562, 1578, 1581, 1609, 1622, 1624, 1645, 1658, 1667, 1691, 1705, 1708, 1715, 1716, 1717, 1721, 1722, 1757, 1767, 1779, 1787, 1809, 1816, 1830, 1872, 1889, 1895, 1901, 1902, 1903, 1926, 1949, 2005, 2006, 2029, 2034, 2037, 2086, 2115, 2125, 2130, 2135, 2136, 2140, 2143, 2160, 2162, 21
# ...

# %%
idx = 0
lis=[]
for file in os.listdir(root_path):
    if idx in s:
        lis.append('/home/pirl/Documents/final_motion_npz/'+file)
        #print('/home/pirl/Documents/final_motion_npz/'+file)
    #print(file)
    idx+=1
print(len(lis))
# Out:
# 10000

# %%
idx = 0
lis=[]
for file in os.listdir(root_path):
    if idx in s:
        #lis.append('/home/pirl/Documents/final_motion_npz/'+file)
        #print(save_path+file)
        shutil.copy('/home/pirl/Documents/final_motion_npz/'+file, save_path+file)
    #print(file)
    idx+=1
#print(len(lis))

# %%
shutil.copy('/home/pirl/Documents/final_motion_npz')
