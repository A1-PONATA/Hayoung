# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Flatten, Dense, Activation
from tensorflow.python.keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.python.keras.layers.core import Dropout
from tensorflow.python.keras.models import load_model
from tensorflow.python.keras.optimizers import Adam
from tensorflow.python.keras.layers.normalization import BatchNormalization

import numpy as np
import glob
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
import numpy as np
import glob
import sys
from sklearn.model_selection import train_test_split

x_train = np.empty((0, 240, 180, 3))
y_train = np.empty((0, 4))

d={'st':0, 'right':0, 'left':0}

training_data = glob.glob('/home/pirl/Documents/motion_prepro_fin240x180/*.npz') #보고싶은 npz파일 입력

for single_npz in training_data:
    with np.load(single_npz) as data:
        x = data['train']
        y=data['training_labels']
        if y[0]==1:
            d['st']=d['st']+1
        if y[1]==1:
            d['right']=d['right']+1
        if y[2]==1:
            d['left']=d['left']+1
        plt.title(y)
        
        plt.imshow(x[0])

        plt.show()
    x = np.reshape(x, (-1, 240, 180, 3))
    x_train = np.vstack((x_train, x))
print(d)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# {'st': 1, 'right': 1, 'left': 1}

# %%
import cv2

# %%
for single_npz in training_data:
    with np.load(single_npz) as data:
        x=data['train']; y=data['training_labels']
        plt.imshow(x[0])
        print(x[0][0][0])
#         plt.imshow(x[0:1,0:1,1])
#         plt.imshow(x[0:1,0:1,2])

        print(x[0].shape)
#         cv2.imshow('image',x)
#         cv2.waitKey(0)
#         cv2.destroyAllWindows()
# cv2.imshow('image', img)
x[0].shape
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [191. 221. 255.]
# (240, 180, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [183. 211. 255.]
# (240, 180, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [31. 16. 46.]
# (240, 180, 3)
# (240, 180, 3)

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(10,10, figsize=(8,8))
for i,ax in enumerate(axes.flat):
    ax.imshow(x[i])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
dfile = "/home/pirl/Documents/motion_prepro_fin240x180/11000.npz"
images = np.load(dfile)["train"]
images.shape
plt.ion()
plt.figure()
plt.imshow(images[0].transpose((0,1,2)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.random.rand(0, 100) # Replace this line with your 90x100 numpy array.
a = np.expand_dims(a, axis = 2)
a = np.concatenate((a, a, a), axis = 2)
print(a.shape)
# (90, 100, 3)
plt.imshow(a)
plt.show()

# %%
img = cv2.imread('/home/pirl/Desktop/11072660637574.jpg',cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
shrink = cv2.resize(img,(240,180))
encoding= np.eye(3)[1]
np.savez('temp_img.npz', train=shrink, trining_label=encoding)

# %%
import matplotlib.pyplot as plt
import numpy as np
dfile = "temp_img.npz"
images = np.load(dfile)["train"]
images.shape
plt.ion()
plt.figure()
plt.imshow(images.transpose((0,1,2)))
